# %% [raw]
# ---
# description: Functionalities to Retrieve the publications
# output-file: retriever.html
# title: retriever
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->
