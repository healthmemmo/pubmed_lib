# %% [raw]
# ---
# description: Result class and all methods to get details and process the publications
# output-file: result.html
# title: result
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# # Fetching some results from search. Should change to a class soon

# %%
class Result(BaseModel):
    """
    Model for results, including all the data taht will be retreived and their type
    """
    pubmed:str
    pmc: Optional[str]
    doi: Optional[str]
    pii: Optional[str]
    abstract: str
    autorlist: List[Autor]
    title: str
    journal: str
    published: Optional[date]
    mayorKeys: List[str]
    mayorMesh: List[str]
    minorMesh: List[str]

# %%
#| echo: false
#| output: asis
show_doc(Result)
# Out:
# ---
#
# [source](https://github.com/Dmaturana81/pubmed_lib/blob/main/pubmed_lib/result.py#L19){target="_blank" style="float:right; font-size:smaller"}
#
# ### Result
#
# >      Result (pubmed:str, pmc:Optional[str]=None, doi:Optional[str]=None,
# >              pii:Optional[str]=None, abstract:str,
# >              autorlist:List[pubmed_lib.author.Autor], title:str, journal:str,
# >              published:Optional[datetime.date]=None, mayorKeys:List[str],
# >              mayorMesh:List[str], minorMesh:List[str])
#
# Model for results, including all the data taht will be retreived and their type
