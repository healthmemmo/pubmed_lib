# %% [raw]
# ---
# description: Module with some data to be use in the treatment of the data
# output-file: data.html
# title: data
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(countries2list)
# Out:
# ---
#
# [source](https://github.com/Dmaturana81/pubmed_lib/blob/main/pubmed_lib/data.py#L443){target="_blank" style="float:right; font-size:smaller"}
#
# ### countries2list
#
# >      countries2list (COUNTRIES)

# %%
#| echo: false
#| output: asis
show_doc(lower_countries)
# Out:
# ---
#
# [source](https://github.com/Dmaturana81/pubmed_lib/blob/main/pubmed_lib/data.py#L435){target="_blank" style="float:right; font-size:smaller"}
#
# ### lower_countries
#
# >      lower_countries (COUNTRIES)
