# %% [raw]
# ---
# description: Functionalities to plot the data
# output-file: viz.html
# title: viz
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(plot_timeline)
# Out:
# ---
#
# [source](https://github.com/Dmaturana81/pubmed_lib/blob/main/pubmed_lib/viz.py#L15){target="_blank" style="float:right; font-size:smaller"}
#
# ### plot_timeline
#
# >      plot_timeline (df, filename=None)

# %%
#| echo: false
#| output: asis
show_doc(plot_countries)
# Out:
# ---
#
# [source](https://github.com/Dmaturana81/pubmed_lib/blob/main/pubmed_lib/viz.py#L40){target="_blank" style="float:right; font-size:smaller"}
#
# ### plot_countries
#
# >      plot_countries (df_det, filename=None)
